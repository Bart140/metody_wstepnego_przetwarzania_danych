# %%
# !uv add pandas
# !uv add numpy
# Out:
# Resolved 97 packages in 706ms
# Prepared 2 packages in 5.42s
# Installed 2 packages in 577ms
#  + numpy==2.4.2
#  + pandas==3.0.1
# Resolved 97 packages in 311ms
# Audited 93 packages in 9ms

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Zadanie 1

# %%
x = [_ for _ in range(1,101)]

# %%
series = pd.Series(x)
# Out:
#   Cell In[11], line 1
#     series = pd.Series(index="ean"+x,x)
#                                       ^
# SyntaxError: positional argument follows keyword argument
